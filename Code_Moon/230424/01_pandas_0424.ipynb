# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
import prettyprint as pp

# %% [markdown]
# # 워드클라우드
# 1. 라이브러리 이름 : wordcloud
#     - 얘 쓰려면 JAVA 설치되어있어야함

# %%
# !pip install wordcloud

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\zino0\appdata\local\programs\python\python311\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\zino0\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\zino0\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\zino0\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (1.24.2)
# Requirement already satisfied: packaging in c:\users\zino0\appdata\local\programs\python\python311\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.0)

# %%
from wordcloud import WordCloud

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
text = open('hiphop.txt', encoding= 'euc-kr').read()

# %%
text
# Out:
# '"보고 싶다\n이렇게 말하니까 더 보고 싶다\n너희 사진을 보고 있어도\n보고 싶다\n너무 야속한 시간\n나는 우리가 밉다\n이젠 얼굴 한번 보는 것 조차\n힘들어진 우리가\n여긴 온통 겨울 뿐이야\n8월에도 겨울이 와\n마음은 시간을 달려가네\n홀로 남은 설국열차\n니 손 잡고 지구 반대편까지 가\n겨울을 끝내고파\n그리움들이 얼마나\n눈처럼 내려야 그 봄날이 올까\nFriend\n허공을 떠도는\n작은 먼지처럼 작은 먼지처럼\n날리는 눈이 나라면\n조금 더 빨리\n네게 닿을 수 있을 텐데\n눈꽃이 떨어져요\n또 조금씩 멀어져요\n보고 싶다 보고 싶다\n보고 싶다 보고 싶다\n얼마나 기다려야\n또 몇 밤을 더 새워야\n널 보게 될까 널 보게 될까\n만나게 될까 만나게 될까\n추운 겨울 끝을 지나\n다시 봄날이 올 때까지\n꽃 피울 때까지\n그곳에 좀 더 머물러줘 \n머물러줘\n니가 변한 건지\n니가 변한 건지\n아니면 내가 변한 건지\n내가 변한 건지\n이 순간 흐르는 시간조차 미워\n우리가 변한 거지 뭐\n모두가 그런 거지 뭐\n그래 밉다 니가 넌 떠났지만\n단 하루도 너를\n잊은 적이 없었지 난\n솔직히 보고 싶은데\n이만 너를 지울게\n그게 널 원망하기보단\n덜 아프니까\n시린 널 불어내 본다\n연기처럼 하얀 연기처럼\n말로는 지운다 해도\n사실 난 아직 널 보내지 못하는데\n눈꽃이 떨어져요\n또 조금씩 멀어져요\n보고 싶다 보고 싶다\n보고 싶다 보고 싶다\n얼마나 기다려야\n또 몇 밤을 더 새워야\n널 보게 될까 널 보게 될까\n만나게 될까 만나게 될까\nYou know it all\nYou\'re my best friend\n아침은 다시 올 거야\n어떤 어둠도 어떤 계절도\n영원할 순 없으니까\n벚꽃이 피나봐요\n이 겨울도 끝이 나요\n보고 싶다 보고 싶다 \n보고 싶다 보고 싶다\n조금만 기다리면\n며칠 밤만 더 새우면\n만나러 갈게 만나러 갈게\n데리러 갈게 데리러 갈게\n추운 겨울 끝을 지나\n다시 봄날이 올 때까지\n꽃 피울 때까지\n그곳에 좀 더 머물러줘 \n머물러줘"\n"No I don\'t wanna go too fast\nCuz nothing really lasts\nI think I need some time\nBut I can\'t get you off my mind\n일단 시작부터\n제일 센 걸로 부탁해 바텐더\n연속해 들이키고 나니\n모두 다 예뻐\n보여 침이 고여\nthese ladies so loyal\n그러다 널 처음 봤어\ngeez girl love me tender\n난 씩씩하게 말을 걸어\n넌 저기 시시한 여자와는 달리\n틱틱 거려 칙칙하던\n분위기에 한 줄기 빛\n설렘 정도가 지나쳐\n마치 사춘기\n훔치는 너의 눈빛에\n입술은 바짝 마르지\n오랜만에 느껴보는 이런 떨림\n이러지도 저러지도 못해 나\n이 밤이 다 가기 전에\n난 널 내 품 안에 원해\nReal love\nI think I wanna just\n고민고민 하지마 Hey\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다 \n에라 모르겠다\n에라 모르겠다 \nGirl I wanna get down\n설렘을 찾고 싶어 마르고 닳도록\n난 여러 명의 포로 도망치네\n이곳 빠삐용\n나 지긋지긋 희끗희끗 흰머리가 나\n양아치 이제 끝 바람둥이 한 가닥\n나라는 남자를 모르던\n그런 네가 좋았지\n몰래 난 원래 모든 Girl\n싫증 잘 느끼는 벌레\n나이를 먹어도 사랑은\n단 1도 모르겠어\n뒤처리를 못해\n피눈물 없는 로맨스\n장단 없는 game\n너는 오락가락하고\n멜로디가 다른 알토와 소프라노\n어차피 우리는 끊어질 거야\n딱 잘라 말할게\n타락해버린 꿈에 Eldorado\n훔치는 너의 눈빛에\n입술은 바짝 마르지\n오랜만에 느껴보는 이런 떨림\n이러지도 저러지도 못해 나\n이 밤이 다 가기 전에\n난 널 내 품 안에 원해\nReal love\nI think I wanna just\n고민고민 하지마 Hey\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down\nYou & me 같이 차를 타고 ride\n술 취했으니 눈 좀 붙여 잠깐만\n어디 가서 쉴까 baby\n난 손만 잡고 자\n속은 뻔해 honey honey\nbut I want it and you know it\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 에라 모르겠다\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down\nGirl I wanna get down\nGirl I wanna get down\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\n에라 모르겠다 I Love ya\nGirl I wanna get down\n에라 모르겠다\n에라 모르겠다\n에라 모르겠다\nGirl I wanna get down"\n"착해 빠진 게 독한 소리 할 때\n분명 지 속도 속 아니었겠죠\n잡는 목소리 머뭇거리지도 않고\n날 떠날 땐 분명 이 악물었겠죠\n상처받지 않은 듯 돌아섰지만\n애같이 눈물을 사탕처럼 \n막 흘리면서 가\n다 흘리면서 가 \n자기보다 큰 슬픔을 \n쇠똥구리처럼 힘겹게 \n굴리면서 가\n난 왜 그런 널 안지 못했을까\n그날 결판 짓던 순간에 \n터널 같던 너의 눈가\n그 생각만 하면 자꾸 내 맘이 짠해\n저기요 좀 찾아주세요 \n그 사람 나 아니면 갈 곳이 없어요\n마른 두 다리로 어딘가 헤맬 텐데\n내가 집이 돼주기로 했는데\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n서로의 심술 맞은 자존심 \n딱 그 정도 거리만큼 \n우린 떨어져 걸었어\n뾰족한 맘 \n괜히 툭 뱉은 말들에 비해 \n진심은 항상 한 박자 느렸어\n그 한 발짝 물러서기가 \n그렇게 힘들어 \n이 꼴 저 꼴 다 본 끝에 \n여기까지네\n30평 아파트가 돼주고 \n싶었는데 \n겨우 원룸밖에 못 돼 줘서 \n미안해\n처음엔 시원했어 너 떠나간 후\n싹 지워냈어 그런 줄 알았어\n근데 아니더라고 나도 모르게 \n익숙한 뒷모습을 몰래 \n따라가더라\n넌 줄 알았어\n친구들은 다 나쁜 년이라고 \n술자리서 욕하는데\n속으론 지들이 뭘 안다고\n니 편들게 되더라 \n머리가 아프네 \n집 가야지 지갑 어디다 뒀더라\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n아저씨 사실 나 갈 곳 없어요\n그 사람 아니면 \n내 마음 둘 곳 없어요\n어딜 가야 다시 볼 수 있을까요\n우리 집을 못 찾겠군요\n아저씨 그 사람 찾아주세요\n그 사람 나 아님 잠들 곳 없어요\n어딜 가야 다시 볼 수 있을까요\n우리 집을 못 찾겠군요\n그리워서 그리워서\n밤하늘 바라봐요\n그대 알아 \n나도 그대 마음과 같아\n시간 지나 사랑이면\n그래도 사랑이면\nLonely you \n돌아와 너의 집으로\n저 골목길 돌면 자주 걷던 길과\n너가 마중 나왔던 버스 정류장\n미용실을 지나\n오르막길 올라서\n가다 보면 어느새 \n불 꺼진 너의 집 앞\n난 믿어\n그리워하다\n언젠가 우연처럼 만나게 될 \n만화 같은 기적 \n그 사람 지금 어디 있을까요\n우리 집을 못 찾겠군요\n돌아봐도 사랑이면\n그래도 사랑이면\n그땐 울고 있는 \n나를 찾아줄래"\n"일이 피곤했나\n오늘따라 한 두 잔에 퍼지네\n반 뼘짜리 위로\n한숨 피우고 나니\n기분이 좀 나아지네\n요즘 들어 사는 게\n봄 가을 같아 좋은 건\n다 짧게 지나가\n어떤 이는 내가 아닌\n나로 나를 만들어\n들었다 놓곤\n스치듯 내 곁을 떠나가\n내가 강해졌던 건지\n무뎌졌던 건지\n일년에 한 두 번\n울먹임을 다했던 내가\n눈물이 다 나네\n가리워진 길\n그 노래가\n내 마음 ...

# %%
okt = Okt()

# Okt 함수를 이용하여, 내용의 형태를 분석
nouns = okt.nouns(text)

# %%
words = [n for n in nouns if len(n) > 1]

# %%
cnt = Counter(words)
cnt
# Out:
# Counter({'보고': 38,
#          '너희': 1,
#          '사진': 5,
#          '시간': 41,
#          '우리': 48,
#          '얼굴': 11,
#          '한번': 6,
#          '조차': 2,
#          '온통': 1,
#          '겨울': 9,
#          '마음': 19,
#          '홀로': 5,
#          '설국열차': 1,
#          '잡고': 15,
#          '지구': 1,
#          '반대편': 1,
#          '끝내': 1,
#          '그리움': 2,
#          '얼마나': 8,
#          '봄날': 3,
#          '허공': 3,
#          '먼지': 3,
#          '나라': 12,
#          '조금': 5,
#          '눈꽃': 2,
#          '지나': 9,
#          '다시': 18,
#          '순간': 11,
#          '거지': 4,
#          '모두': 27,
#          '하루': 7,
#          '그게': 12,
#          '연기': 5,
#          '해도': 15,
#          '사실': 9,
#          '아침': 4,
#          '어둠': 3,
#          '계절': 2,
#          '벚꽃': 1,
#          '피나': 1,
#          '며칠': 3,
#          '일단': 4,
#          '시작': 9,
#          '제일': 2,
#          '부탁': 3,
#          '바텐더': 1,
#          '연속': 3,
#          '나니': 2,
#          '고여': 1,
#          '처음': 5,
#          '저기': 2,
#          '여자': 16,
#          '달리': 6,
#          '틱틱': 1,
#          '거려': 1,
#          '분위기': 6,
#          '줄기': 1,
#          '정도': 4,
#          '마치': 6,
#          '사춘기': 1,
#          '눈빛': 6,
#          '입술': 4,
#          '바짝': 2,
#          '마르지': 5,
#          '가기': 4,
#          '고민': 8,
#          '마르고': 1,
#          '여러': 1,
#          '명의': 2,
#          '포로': 1,
#          '빠삐용': 1,
#          '지긋지긋': 1,
#          '희끗희끗': 1,
#          '머리': 9,
#          '아치': 1,
#          '이제': 40,
#          '바람둥이': 1,
#          '가닥': 1,
#          '남자': 11,
#          '몰래': 2,
#          '원래': 2,
#          '모든': 29,
#          '싫증': 1,
#          '벌레': 1,
#          '나이': 2,
#          '사랑': 50,
#          '처리': 1,
#          '눈물': 26,
#          '로맨스': 1,
#          '장단': 1,
#          '오락가락': 1,
#          '멜로디': 6,
#          '다른': 8,
#          '알토': 1,
#          '소프라노': 1,
#          '어차피': 6,
#          '타고': 3,
#          '취했으': 1,
#          '잠깐': 4,
#          '어디': 28,
#          '소리': 14,
#          '분명': 4,
#          '속도': 1,
#          '목소리': 6,
#          '상처': 9,
#          '사탕': 1,
#          '자기': 2,
#          '슬픔': 4,
#          '쇠똥구리': 1,
#          '면서': 1,
#          '안지': 1,
#          '그날': 4,
#          '결판': 1,
#          '터널': 2,
#          '눈가': 1,
#          '생각': 30,
#          '자꾸': 4,
#          '사람': 24,
#          '다리': 1,
#          '어딘가': 2,
#          '밤하늘': 3,
#          '그대': 20,
#          '이면': 9,
#          '서로': 12,
#          '심술': 1,
#          '자존심': 2,
#          '거리': 6,
#          '우린': 19,
#          '진심': 6,
#          '항상': 11,
#          '박자': 1,
#          '발짝': 1,
#          '지네': 1,
#          '아파트': 1,
#          '겨우': 3,
#          '원룸': 1,
#          '뒷모습': 1,
#          '친구': 13,
#          '술자리': 1,
#          '가야': 4,
#          '지갑': 2,
#          '아저씨': 3,
#          '골목길': 1,
#          '자주': 1,
#          '마중': 1,
#          '버스': 1,
#          '정류장': 1,
#          '미용실': 1,
#          '오르막': 1,
#          '우연': 1,
#          '만화': 1,
#          '기적': 2,
#          '지금': 40,
#          '그땐': 3,
#          '오늘': 53,
#          '위로': 24,
#          '한숨': 2,
#          '기분': 5,
#          '요즘': 4,
#          '가을': 1,
#          '나로': 6,
#          '무뎌졌던': 1,
#          '노래': 14,
#          '이유': 5,
#          '스트레스': 1,
#          '버티고': 1,
#          '증발': 1,
#          '대가': 1,
#          '그냥': 19,
#          '어도': 3,
#          '엄지': 3,
#          '라며': 1,
#          '주병': 1,
#          '마흔': 1,
#          '담배': 3,
#          '구름': 5,
#          '우릴': 8,
#          '기침': 1,
#          '웃음': 4,
#          '잠시': 2,
#          '혼자': 10,
#          '때론': 9,
#          '우울': 1,
#          '불운': 1,
#          '나태': 1,
#          '그물': 1,
#          '물음': 2,
#          '머릿속': 6,
#          '계속': 16,
#          '현실': 4,
#          '유령': 1,
#          '고독': 1,
#          '무덤': 3,
#          '후렴': 1,
#          '누군가': 4,
#          '역시': 7,
#          '외로워': 1,
#          '평점': 1,
#          '채점': 1,
#          '몇몇': 1,
#          '문턱': 1,
#          '가끔': 17,
#          '사나': 1,
#          '도대체': 4,
#          '가나': 1,
#          '가면': 2,
#          '가명': 1,
#          '갈피': 1,
#          '계산': 1,
#          '가치': 3,
#          '거짓': 2,
#          '껍질': 1,
#          '세상': 27,
#          '장난': 3,
#          '판단': 1,
#          '바람': 9,
#          '하나': 75,
#          '추억': 4,
#          '동경': 4,
#          '어머니': 6,
#          '당신': 16,
#          '하늘': 24,
#          '우러러': 2,
#          '부끄러움': 2,
#          '무기': 1,
#          '첩방': 1,
#          '등불': 1,
#          '기억': 20,
#          '용기': 2,
#          '내지': 2,
#          '대신': 5,
#          '연필': 1,
#          '창살': 1,
#          '건너편': 1,
#          '이름': 22,
#          '헤던': 4,
#          '비판': 1,
#          '비아': 1,
#          '입가': 2,
#          '시대': 1,
#          '고개': 6,
#          '한국인': 1,
#          '한국': 4,
#          '촛불': 2,
#          '설움': 1,
#          '죄책감': 2,
#          '철인': 1,
#          '자화상': 1,
#          '걸음': 2,
#          '시가': 1,
#          '광장': 1,
#          '가슴속': 3,
#          '만주': 1,
#          '일본': 2,
#          '누구': 14,
#          '이기': 1,
#          '명예': 4,
#          '시인': 1,
#          '접기': 2,
#          '프린트': 2,
#          '가사': 12,
#          '오류': 2,
#          '신고': 2,
#          '작사': 2,
#          '작곡': 2,
#          '혹시': 11,
#          '별도': 8,
#          '피해': 5,
#          '내겐': 6,
#          '두운': 1,
#          '온대': 1,
#          '보이지': 6,
#          '자리': 6,
#          '리기': 1,
#          '기도': 8,
#          '매일': 12,
#          '과정': 1,
#          '이후': 1,
#          '흔적': 1,
#          '수도': 4,
#          '살때': 3,
#          '피아노': 4,
#          '영재': 4,
#          '베토벤': 4,
#          '모짜르트': 3,
#          '바흐': 3,
#          '쇼팽': 3,
#          '선배': 4,
#          '새끼': 5,
#          '엿먹어': 3,
#          '베르사체': 3,
#          '무한리필': 3,
#          '악장': 9,
#          '하얀색': 3,
#          '대리석': 3,
#          '바로': 13,
#          '지휘봉': 3,
#          '수트': 1,
#          '바지': 3,
#          '부자': 1,
#          '거의': 1,
#          '젠틀': 1,
#          '건희': 1,
#          '칭호': 1,
#          '노창': 1,
#          '방금': 3,
#          '라인': 2,
#          '리스크': 1,
#          '첨벙': 1,
#          '비닐': 1,
#          '살기': 2,
#          '위해': 22,
#          '숨구멍': 1,
#          '악보': 1,
#          '따윈': 5,
#          '동네': 2,
#          '구덩이': 1,
#          '선언': 1,
#          '자신': 7,
#          '임임': 1,
#          '박아': 3,
#          '소나타': 1,
#          '오직': 10,
#          '그것': 2,
#          '안해': 2,
#          '카포': 1,
#          '절대로': 7,
#          '박수': 2,
#          '할렐루야': 2,
#          '파우스트': 1,
#          '괴테': 1,
#          '고흐': 1,
#          '아인슈타인': 1,
#          '노멀': 1,
#          '엿먹': 1,
#          '여기': 20,
#          '예술': 3,
#          '전당': 1,
#          '마에스트로': 1,
#          '계급': 1,
#          '백건우': 1,
#          '카라얀': 1,
#          '클래식': 1,
#          '용어': 1,
#          '이력': 1,
#          '전용': 1,
#          '보드': 1,
#          '고장': 1,
#          '맥북': 1,
#          '위인': 28,
#          '세종': 3,
#          '연주': 1,
#          '마지막': 8,
#          '영혼': 2,
#          '이건': 9,
#          '주문': 1,
#          '날개': 10,
#          '악마': 1,
#          '어서': 4,
#          '이상': 4,
#          '취해': 1,
#          '위스키': 1,
#          '정신': 7,
#          '비밀': 1,
#          '감옥': 1,
#          '중독': 1,
#          '깊이': 1,
#          '성배': 1,
#          '손길': 1,
#          '거부': 1,
#          '소릴': 2,
#          '내일': 13,
#          '알람': 1,
#          '안고': 1,
#          '후회': 2,
#          '보지': 4,
#          '사람과': 3,
#          '오해': 2,
#          '그녀': 5,
#          '웃기': 1,
#          '만큼': 2,
#          '이별': 5,
#          '이해': 5,
#          '당장': 2,
#          '아무': 12,
#          '만약': 4,
#          '전화': 6,
#          '말투': 2,
#          '행동': 3,
#          '친굴': 1,
#          '만날': 2,
#          '눈치': 3,
#          '자격': 1,
#          '방법': 4,
#          '절대': 22,
#          '죽지': 5,
#          '기어': 1,
#          '겨눠': 2,
#          '조준': 8,
#          '발사': 8,
#          '뱁새': 5,
#          '성공': 3,
#          '차트': 1,
#          '덤블링': 1,
#          '트램펄린': 1,
#          '누가': 15,
#          '수가': 11,
#          '실패': 2,
#          '전부': 6,
#          '방탄': 1,
#          '두려움': 4,
#          '따위': 1,
#          '유리천장': 1,
#          '부숴': 1,
#          '승리': 1,
#          '무릎': 4,
#          '손목': 3,
#          '길거릴': 2,
#          '도배': 3,
#          '노랜': 2,
#          '놀이': 2,
#          '보기': 5,
#          '범죄': 2,
#          '마이크': 2,
#          '불과': 1,
#          '장악': 1,
#          '뭉치': 1,
#          '닥치고': 1,
#          '콘텐츠': 1,
#          '과시': 1,
#          '부담': 2,
#          '소재': 1,
#          '인터넷': 2,
#          '접속': 1,
#          '오브': 1,
#          '역할': 2,
#          '메인': 1,
#          '세대': 1,
#          '대세': 2,
#          '장래희망': 1,
#          '얼간이': 1,
#          '동선': 1,
#          '무대': 13,
#          '작업실': 1,
#          '오천만': 1,
#          '하쿠나마타타': 1,
#          '누울': 2,
#          '제대로': 2,
#          '소파': 2,
#          '공기': 3,
#          '황인종': 1,
#          '먹듯': 1,
#          '실검': 1,
#          '실력': 2,
#          '예의': 1,
#          '시비': 1,
#          '목적': 2,
#          '첫째': 1,
#          '악의': 1,
#          '단지': 1,
#          '티켓': 2,
#          '매진': 2,
#          '차기작': 1,
#          '장관': 1,
#          '바닥': 2,
#          '높이': 3,
#          '과로': 1,
#          '체질': 1,
#          '링거': 1,
#          '투혼': 1,
#          '휴가': 1,
#          '반납': 1,
#          '뇌물': 1,
#          '위법': 1,
#          '그림': 7,
#          '일부': 1,
#          '일거수일투족': 1,
#          '세간': 1,
#          '집중': 3,
#          '논란': 1,
#          '재기': 1,
#          '탄력': 1,
#          '절제': 1,
#          '증명': 2,
#          '안중': 1,
#          '에이': 2,
#          '재수': 1,
#          '삼각관계': 1,
#          '바다': 4,
#          '직직직': 1,
#          '의식': 1,
#          '대부분': 2,
#          '착각': 1,
#          '심장': 6,
#          '아주': 8,
#          '귓가': 1,
#          '휘파람': 5,
#          '점점': 4,
#          '가까이': 2,
#          '파라파라': 5,
#          '파라': 4,
#          '느낌': 15,
#          '갈수록': 1,
#          '마음속': 1,
#          '게임': 4,
#          '택해': 1,
#          '가로': 1,
#          '인연': 1,
#          '필요': 3,
#          '어른': 3,
#          '유년기': 1,
#          '시절': 1,
#          '존재': 6,
#          '전쟁': 2,
#          '실망': 2,
#          '행복': 4,
#          '조바심': 1,
#          '꽁무니': 1,
#          '악몽': 1,
#          '사고': 1,
#          '방식': 3,
#          '열쇠': 1,
#          '꾸러미': 1,
#          '노력': 2,
#          '미리': 3,
#          '미래': 10,
#          '거짓말': 15,
#          '뒷골목': 1,
#          '해방': 3,
#          '반창고': 1,
#          '최초': 2,
#          '서서': 1,
#          '우주': 1,
#          '별로': 2,
#          '가장': 2,
#          '실행': 2,
#          '결론': 2,
#          '두발': 4,
#          '태양': 4,
#          '고통': 1,
#          '몸부림': 1,
#          '어쩌면': 3,
#          '마법': 1,
#          '거북선': 1,
#          '판옥선': 1,
#          '천자총통': 1,
#          '발포': 1,
#          '명량': 1,
#          '무한도전': 1,
#          '필욘': 1,
#          '충무공': 1,
#          '역사': 31,
#          '공부': 2,
#          '영화': 3,
#          '이순신': 1,
#          '동상': 1,
#          '동장군': 1,
#          '오기': 1,
#          '하나로': 1,
#          '영웅': 3,
#          '나와라': 1,
#          '울돌목': 1,
#          '시국': 1,
#          '레드': 1,
#          '오션': 1,
#          '격군': 1,
#          '장군': 2,
#          '양반': 1,
#          '노비': 3,
#          '국민': 3,
#          '이란': 1,
#          '단어': 1,
#          '오버': 1,
#          '덜덜': 1,
#          '멀미': 8,
#          '아버지': 7,
#          '정답': 3,
#          '준비': 3,
#          '화살': 19,
#          '휙휙': 5,
#          '난중일기': 1,
#          '신발': 2,
#          '명품': 1,
#          '짚신': 1,
#          '서울': 3,
#          '복판': 1,
#          '지사': 1,
#          '자세': 3,
#          '신들': 1,
#          '명감': 1,
#          '유감': 1,
#          '십상시': 1,
#          '이루리': 1,
#          '내포': 1,
#          '근성': 1,
#          '여태': 3,
#          '동전': 1,
#          '선조': 1,
#          '함성': 1,
#          '똑바로': 1,
#          '그때': 4,
#          '간다': 3,
#          '어쩜': 1,
#          '만남': 2,
#          '대도': 2,
#          '하루하루': 1,
#          '로만': 4,
#          '꿈속': 3,
#          '성질': 1,
#          '불씨': 1,
#          '만난': 3,
#          '탄생': 1,
#          '밤새': 5,
#          '하모니': 1,
#          '불꽃': 1,
#          '사체': 1,
#          '감상': 2,
#          '명작': 1,
#          '가슴': 4,
#          '보이': 4,
#          '무슨': 6,
#          '바보': 2,
#          '미소': 6,
#          '자꾸만': 1,
#          '일지': 1,
#          '아픔': 2,
#          '선택': 5,
#          '길이': 8,
#          '운명': 1,
#          '지은': 1,
#          '죗값일': 1,
#          '온기': 1,
#          '적의': 1,
#          '걱정': 6,
#          '깃털': 1,
#          '아보': 1,
#          '거란': 3,
#          '믿음': 10,
#          '신념': 2,
#          '가득': 2,
#          '웃음소리': 1,
#          '가지': 6,
#          '일로': 1,
#          '위함': 1,
#          '미약': 1,
#          '비약': 1,
#          '새꺄': 1,
#          '고작': 1,
#          '비행': 1,
#          '훨훨': 1,
#          '영영': 1,
#          '무거워': 1,
#          '물든': 1,
#          '힘껏': 1,
#          '택했어': 1,
#          '조건': 1,
#          '예전': 4,
#          '소녀': 9,
#          '핑계': 1,
#          '대해': 3,
#          '소망': 3,
#          '공존': 1,
#          '거짓말쟁이': 1,
#          '매번': 4,
#          '헛된': 4,
#          '바램': 1,
#          '인정': 1,
#          '무의식': 1,
#          '가게': 1,
#          '집착': 3,
#          '자각': 1,
#          '하진': 1,
#          '자고': 3,
#          '차례': 3,
#          '예감': 1,
#          '날씨': 3,
#          '맥박': 1,
#          '어제': 9,
#          '왜냐면': 3,
#          '중심': 1,
#          '주인공': 2,
#          '마냥': 6,
#          '마찬가지': 1,
#          '실상': 1,
#          '증거': 1,
#          '대로': 11,
#          '축복': 1,
#          '벌린': 1,
#          '향기': 2,
#          '감고': 1,
#          '사막': 1,
#          '가운데': 1,
#          '리도': 1,
#          '정말': 5,
#          '혼란': 3,
#          '비바람': 3,
#          '출구': 3,
#          '개미': 2,
#          '찾기': 1,
#          '방황': 1,
#          '쓸모': 1,
#          '좌절': 3,
#          '기약': 1,
#          '희망이': 1,
#          '안녕': 2,
#          '대한민국': 5,
#          '부재': 1,
#          '브랜드': 1,
#          '평판': 1,
#          '섭외': 1,
#          '순위': 1,
#          '인증': 1,
#          '확인': 1,
#          '일상': 1,
#          '대기업': 2,
#          '회장': 1,
#          '식사': 1,
#          '상상': 4,
#          '눈앞': 3,
#          '직장': 1,
#          '기사': 2,
#          '제목': 1,
#          '열풍': 1,
#          '쉐키들': 1,
#          '열폭': 1,
#          '인기': 4,
#          '듯해': 1,
#          '연구': 1,
#          '엄마': 4,
#          '흐름': 1,
#          '선구자': 1,
#          '사칭': 1,
#          '그린': 6,
#          '척척': 15,
#          '애인': 1,
#          '여자친구': 1,
#          '먼저': 7,
#          '감사': 1,
#          '하나님': 1,
#          '회개': 1,
#          '팽이': 1,
#          '외국인': 1,
#          '숙녀': 1,
#          '촬영': 1,
#          '타투': 1,
#          '테이프': 1,
#          '이태원': 1,
#          '여유': 1,
#          '구해': 1,
#          '용서': 1,
#          '목요일': 1,
#          '거래': 1,
#          '유명인': 1,
#          '대전': 1,
#          '대구': 1,
#          '래퍼': 4,
#          '용돈': 1,
#          '엄말': 1,
#          '쟤넨': 1,
#          '의미': 2,
#          '날짜': 1,
#          '나비': 1,
#          '날갯짓': 1,
#          '크리스탈': 1,
#          '더욱': 1,
#          '어깨': 4,
#          '제발': 2,
#          '갈래': 2,
#          '모자': 1,
#          '불안': 1,
#          '때문': 9,
#          '프라다': 2,
#          '샤넬': 2,
#          '엘라': 2,
#          '자격지심': 8,
#          '언제': 4,
#          '기스같': 1,
#          '별거': 1,
#          '도시': 2,
#          '압구정': 1,
#          '위안': 1,
#          '거릴': 2,
#          '발해': 1,
#          '냉수': 1,
#          '커피': 1,
#          '과거': 1,
#          '빠삭하': 1,
#          '대체': 4,
#          '더위': 1,
#          '주위': 1,
#          '내게로': 2,
#          '만해': 4,
#          '여름': 8,
#          '햇볕': 2,
#          '주말': 3,
#          '간의': 1,
#          '감정': 2,
#          '향수': 1,
#          '뿌리': 2,
#          '고이': 1,
#          '조던': 1,
#          '오늘이': 2,
#          '전화번호': 1,
#          '이야기': 4,
#          '번의': 1,
#          '다음': 2,
#          '복종': 1,
#          '죽음': 2,
#          '자유': 7,
#          '쟁투': 1,
#          '목숨': 4,
#          '후손': 2,
#          '지배자': 2,
#          '타국': 1,
#          '대지': 1,
#          '외로움': 1,
#          '사나이': 1,
#          '고향': 1,
#          '녀석': 1,
#          '건곤': 1,
#          '감리': 1,
#          '사이': 3,
#          '피로': 1,
#          '독립': 1,
#          '하얼빈': 1,
#          '방아쇠': 1,
#          '민족': 3,
#          '조국': 1,
#          '총성': 1,
#          '코레아': 3,
#          '만세': 25,
#          '방랑자': 1,
#          '날인': 1,
#          '듯이': 3,
#          '운동': 1,
#          '자신감': 3,
#          '혁명': 1,
#          '파괴': 1,
#          '재창': 1,
#          '축제': 1,
#          '지난': 1,
#          '밀리': 1,
#          '창밖': 1,
#          '올해': 1,
#          '손바닥': 1,
#          '횟수': 1,
#          '라인업': 1,
#          '음악': 2,
#          '루즈': 1,
#          '몸짓': 1,
#          '주춤': 1,
#          '온도': 2,
#          '아래': 1,
#          '발길': 1,
#          '거랬어': 1,
#          '성탄절': 1,
#          '선물': 1,
#          '조명': 1,
#          '각자': 1,
#          '꽃길': 1,
#          '일만': 1,
#          '너넨': 6,
#          '아이돌': 1,
#          '비디오': 1,
#          '덕분': 1,
#          '고딩': 1,
#          '짝짝': 1,
#          '끼리': 1,
#          '그림자': 1,
#          '감당': 1,
#          '화양연화': 1,
#          '일이': 5,
#          '나발': 1,
#          '가위바위보': 1,
#          '판이': 1,
#          '만하': 1,
#          '불한당': 1,
#          '비쥬': 6,
#          '깡패': 6,
#          '마음껏': 6,
#          '인생': 9,
#          '반복': 1,
#          '시행착오': 1,
#          '대기': 1,
#          '번호': 3,
#          '손자': 1,
#          '손녀': 1,
#          '며느리': 1,
#          '아들': 1,
#          '완전': 4,
#          '환자': 4,
#          '팔자': 4,
#          '먹기': 1,
#          '억지로': 4,
#          '흉내내': 1,
#          '딱지': 1,
#          '예술가': 1,
#          '다시금': 1,
#          '발자취': 1,
#          '증인': 1,
#          '권능': 1,
#          '주머니': 3,
#          '위치': 5,
#          '일시': 1,
#          '영원': 1,
#          '유행': 1,
#          '집합': 1,
#          '이빨': 1,
#          '이어폰': 1,
#          '주름': 2,
#          '점차': 1,
#          '스물넷': 1,
#          '매달': 1,
#          '십일조': 1,
#          '봉투': 1,
#          '회사': 2,
#          '관심': 3,
#          '현재': 1,
#          '나무': 1,
#          '저걸': 1,
#          '운세': 1,
#          '진짜': 5,
#          '여기저기': 1,
#          '최고': 4,
#          '카메라': 1,
#          '정작': 1,
#          '오지': 1,
#          '멀리': 9,
#          '잔고': 1,
#          '수록': 1,
#          '우상': 3,
#          '평생': 3,
#          '절하': 1,
#          '한계': 2,
#          '내적': 1,
#          '매듭': 2,
#          '개척': 1,
#          '세계': 1,
#          '무언가': 1,
#          '얻지': 2,
#          '주님': 2,
#          '영광': 1,
#          '평화': 3,
#          '신의': 3,
#          '증오': 2,
#          '부정': 2,
#          '에너지': 1,
#          '그리네': 1,
#          '발음': 3,
#          '딕션': 3,
#          '방송': 1,
#          '패턴': 1,
#          '질라': 1,
#          '사물놀이': 1,
#          '괴물': 1,
#          '꼬리': 2,
#          '동물원': 1,
#          '무플': 1,
#          '악플': 1,
#          '알받이': 1,
#          '멋대로': 3,
#          '연행': 1,
#          '결백': 1,
#          '만족': 2,
#          '바느질': 1,
#          '가능': 1,
#          '포기': 3,
#          '리그': 1,
#          '플레이어': 1,
#          '감독': 1,
#          '그릴': 1,
#          '발바닥': 1,
#          '클릭': 1,
#          '내년': 1,
#          '야망': 1,
#          '대고': 1,
#          '이자': 3,
#          '대인배': 1,
#          '해이': 1,
#          '갱생': 1,
#          '계획': 2,
#          '인스타': 2,
#          '위엔': 1,
#          '도움닫기': 1,
#          '차이': 5,
#          '똥차': 1,
#          '콩깍지': 1,
#          '몽땅': 1,
#          '농락': 1,
#          '송장': 1,
#          '면상': 1,
#          '부디': 2,
#          '티나': 2,
#          '진리': 1,
#          '이치': 1,
#          '전해': 2,
#          '그대로': 1,
#          '세기': 8,
#          '처럼': 3,
#          '노예': 1,
#          ...})

# %%
! python --version
# Out:
# Python 3.11.2

# %%
img = Image.open('rokmc.png')
img_array = np.array(img)

wc  = WordCloud(
    font_path= 'malgun',
    width = 400,
    height = 400,
    scale = 2.0,
    max_font_size = 250,
    max_words= 50,
    mask= img_array
)

gen = wc.generate_from_frequencies(cnt)
plt.figure()
plt.axis('off')
plt.imshow(gen)
