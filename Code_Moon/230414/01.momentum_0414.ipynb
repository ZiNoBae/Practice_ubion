# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 절대 모멘텀
# 1. 주식 데이터 로드
# 2. 파생 변수 -> Date 컬럼에서 년-월 추출 후 대입
# 3. 년, 월 별  마지막 날의 month_last_dt 데이터프레임 생성
# 4. 전월의 종가를 가지는 파생변수 하나 생성
# 5. 전년도의 종가를 가지는 파생변수 하나 생성
# 6. 전월, 전년도의 종가를 가지고 거래내역 생성
# 7. 수익률 계산

# %%
df = pd.read_csv('../csv/GDX.csv', index_col= 'Date')
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224  197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393  620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480  638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867  367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640  269400

# %%
test_df = df.copy()

# %%
df.index # type : object 네? -> 시계열로 바꾸자
# Out:
# Index(['2006-05-22', '2006-05-23', '2006-05-24', '2006-05-25', '2006-05-26',
#        '2006-05-30', '2006-05-31', '2006-06-01', '2006-06-02', '2006-06-05',
#        ...
#        '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14', '2019-06-17',
#        '2019-06-18', '2019-06-19', '2019-06-20', '2019-06-21', '2019-06-24'],
#       dtype='object', name='Date', length=3295)

# %%
# index 시계열로

pd.to_datetime(df.index, format = '%Y-%m-%d')
# Out:
# DatetimeIndex(['2006-05-22', '2006-05-23', '2006-05-24', '2006-05-25',
#                '2006-05-26', '2006-05-30', '2006-05-31', '2006-06-01',
#                '2006-06-02', '2006-06-05',
#                ...
#                '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14',
#                '2019-06-17', '2019-06-18', '2019-06-19', '2019-06-20',
#                '2019-06-21', '2019-06-24'],
#               dtype='datetime64[ns]', name='Date', length=3295, freq=None)

# %%
# map 함수 -> map(함수(x) or lambda x : , x가져올 데이터(리스트형태) )
# apply() 랑 비슷한데 
# 리스트 형태서 값 하나하나씩 함수에 집어넣을 때는 map함수 
# 시리즈, 데이터프레임 에서 값 하나하나씩 함수에 집어넣을때는 apply()

#map도 lambda 사용 가능 


x = [1,2,3,4]
# def change(x) :
#     return x**2
# list(map(change, x))

list(map(lambda y : y**2, x))
# Out:
# [1, 4, 9, 16]

# %%
from datetime import datetime

# %%
# datetime 라이브러리를 이용하여 시계열로 변경



# Case I

df.index = pd.to_datetime(df.index, format = '%Y-%m-%d')

# %% [markdown]
# ### to_datetime의 기능을 구현 Case 2

# %%
# Case 2 

test_df = test_df.reset_index()
test_df['Date'] = test_df['Date'].apply(lambda x : datetime.strptime(x, '%Y-%m-%d'))
test_df.set_index('Date')
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
# [3295 rows x 6 columns]

# %%
# Case 2 w/ map함수

test_df.index

def change(x) :
    return datetime.strptime(x, '%Y-%m-%d')

test_df.index = list(map(change, test_df.index))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 def change(x) :
#       6     return datetime.strptime(x, '%Y-%m-%d')
# ----> 8 test_df.index = list(map(change, test_df.index))
#
# Cell In[10], line 6, in change(x)
#       5 def change(x) :
# ----> 6     return datetime.strptime(x, '%Y-%m-%d')
#
# TypeError: strptime() argument 1 must be str, not int

# %%
test_df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
# [3295 rows x 6 columns]

# %%
# 새로운 파생변수 년-월의 데이터를 대입 

#strptime : str -> 시계열
#strftime : 시계열 -> str

df['STD - YM'] = list(map(lambda x : datetime.strftime(x, '%Y-%m'), df.index))

# %%
# 월별 마지막 인덱스만 추출하여 새로운 dataframe에 대입
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 # 월별 마지막 인덱스만 추출하여 새로운 dataframe에 대입
# ----> 3 df.index[1]['%Y']
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
def lastday(x) :
    
    for i in df['STD - YM'] :
        if df['STD - YM'][i] != df['STD - YM'][i+1] : 
            df_last = df.iloc[i]
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
#            STD - YM
# Date
# ...

# %%
# Moon

# Case I -> shift 사용 방법
# 'STD - YM'의 현재값과 다음행값이 다른 경우

df.loc[df['STD - YM'] != df.shift(-1)['STD - YM']]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#            STD - YM
# Date
# 2006-05-31  2006-05
# ...

# %%
# Case II -> for문 

month_list_df = pd.DataFrame()

_list = df['STD - YM'].unique()

for i in _list :
    last_df = df.loc[df['STD - YM'] ==  i].tail(1)
    month_list_df = pd.concat([month_list_df, last_df])

month_list_df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#            STD - YM
# Date
# 2006-05-31  2006-05
# ...

# %%
# 전월의 종가를 가지는 파생변수(BF_1M)를 생성하고 결측치는 0으로 대체
# 전년도의 종가를 가지는 파생변수(BF_12M)를 생성하고 결측치는 0으로 대체


month_list_df['BF_1M'] = month_list_df.shift(1)['Adj Close'].fillna(0)

# %%
month_list_df['BF_12M'] = month_list_df.shift(12)['Adj Close'].fillna(0)

# %%
month_list_df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#            STD - YM      BF_1M     BF_12M
# Date
# ...

# %%
# 거래 내역 추가 
# 구매 조건 -> ((전월 종가 / 전년도 종가) - 1)의 값이 0보다 크고 무한대가 아닌 경우 
# : 전년도 대비 전월이 더 올랐어? 그럼 사야지 

df['trade'] = ''

for i in month_list_df.index : 
    signal = ''
    
    # 절대 모멘텀 계산
    momentum_index = month_list_df.loc[i, 'BF_1M']/ month_list_df.loc[i, 'BF_12M'] - 1 

    # 절대 모멘텀 지표에 따라 True or False 로   구분  

    flag = True if (momentum_index > 0) & (momentum_index != -np.inf) & (momentum_index != np.inf) else False 

    if flag :   # flag 자체가 bool형 데이타라 얘 자체가 조건식 
        signal = 'buy'

    print('날짜 : ', i, '모멘텀 인덱스 : ', momentum_index, 'flag : ', flag, 'signal : ', signal)

    df.loc[i, 'trade'] = signal
# Out:
# 날짜 :  2006-05-31 00:00:00 모멘텀 인덱스 :  nan flag :  False signal :
# 날짜 :  2006-06-30 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-07-31 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-08-31 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-09-29 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-10-31 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-11-30 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2006-12-29 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2007-01-31 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2007-02-28 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2007-03-30 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2007-04-30 00:00:00 모멘텀 인덱스 :  inf flag :  False signal :
# 날짜 :  2007-05-31 00:00:00 모멘텀 인덱스 :  0.02123525695897932 flag :  True signal :  buy
# 날짜 :  2007-06-29 00:00:00 모멘텀 인덱스 :  0.014827231670955676 flag :  True signal :  buy
# ...

# %%
df['trade'].value_counts()
# Out:
#        3234
# buy      61
# Name: trade, dtype: int64

# %% [markdown]
# ### 수익률 계산
# 1. 파생변수(return)값은 1로 생성
# 2. rtn = 1.0, buy, sell 변수는 0으로 생성
# 3. 반복문을 이용해서 현재의 trade가 buy이고, 전행의 trade가 '' 이면, 구매
# 4. 전행의 trade가 buy이고, 현재의 trade가 ''이면, 판매날
# 5. 수익률 계산해서 return 대입
#
# ### 누적수익률 계산
# 1. acc_rtn = 1.0 생성
# 2. return의 항목들을 누적 곱하여 acc_rtn 컬럼에 대입
# 3. 최종적으로 acc_rtn

# %%
df['return'] = 1
df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
#            STD - YM trade  return
# ...

# %%
#  수익률 만들자 

df['return'] = 1

rtn = 1.0

buy = 0
sell = 0

for i in df.index :
    if (df.loc[i, 'trade'] == 'buy') & (df.shift(1).loc[i, 'trade'] == '') : 
        buy = df.shift(1).loc[i, 'Adj Close']
    
    elif (df.shift(1).loc[i, 'trade'] == 'buy') & (df.loc[i, 'trade'] == '') : 
        sell = df.shift(1).loc[i, 'Adj Close']
        
        rtn = (sell-buy)/buy + 1

        df.loc[i,'return'] = rtn

      

df['return'].value_counts()
# Out:
# 1.000000    3234
# 1.028235       1
# 1.014928       1
# 1.007713       1
# 1.015013       1
#             ...
# 0.999615       1
# 1.011326       1
# 1.009224       1
# 0.989736       1
# 1.002399       1
# Name: return, Length: 62, dtype: int64

# %%
# for 문 누적곱 trial

acc_rtn = 1

# %%
# 누적수익률 만들자 cumprud? cumprod

df['return'].cumprod()
# Out:
# Date
# 2006-05-22    1.000000
# 2006-05-23    1.000000
# 2006-05-24    1.000000
# 2006-05-25    1.000000
# 2006-05-26    1.000000
#                 ...
# 2019-06-18    1.184806
# 2019-06-19    1.184806
# 2019-06-20    1.184806
# 2019-06-21    1.184806
# 2019-06-24    1.184806
# Name: return, Length: 3295, dtype: float64

# %%
# Moon
df['return'] = 1
rtn = 1.0
buy = 0
sell = 0

for i in df.index : 
    # i 를 df.index 로 쓸수 잇는것은 얘가 중복된 값이 없어서 가능한 것. 
    
    # 구매한 날 체크 & 구매가 지정 
    if ((df.loc[i, 'trade']) == 'buy') and (df.shift(1).loc[i, 'trade'] == '') : 
        buy = df.loc[i, 'Adj Close']
        print('진입일 :',i, '구입가격 : ', buy)

    # 판매한 날 체크, 판매가 지정, 수익률 계산 
    elif (df.loc[i, 'trade'] == '') and (df.shift(1).loc[i, 'trade'] == 'buy') :
        sell = df.loc[i, 'Adj Close']
        rtn = (sell - buy)/buy + 1

        df.loc[i, 'return'] = rtn
        print('판매일', i, '판매가격', sell, "수익률", rtn)
# Out:
# 진입일 : 2007-05-31 00:00:00 구입가격 :  36.162109
# 판매일 2007-06-01 00:00:00 판매가격 36.993214 수익률 1.0229827580023056
# 진입일 : 2007-06-29 00:00:00 구입가격 :  34.989338
# 판매일 2007-07-02 00:00:00 판매가격 35.866615 수익률 1.0250726950021176
# 진입일 : 2007-09-28 00:00:00 구입가격 :  41.878242
# 판매일 2007-10-01 00:00:00 판매가격 42.312256 수익률 1.010363711065044
# 진입일 : 2007-10-31 00:00:00 구입가격 :  46.72633
# 판매일 2007-11-01 00:00:00 판매가격 45.082588 수익률 0.9648219323024086
# 진입일 : 2007-11-30 00:00:00 구입가격 :  42.810921
# 판매일 2007-12-03 00:00:00 판매가격 43.235706 수익률 1.00992235135516
# 진입일 : 2007-12-31 00:00:00 구입가격 :  43.033947
# 판매일 2008-01-02 00:00:00 판매가격 46.235912 수익률 1.0744055617301382
# 진입일 : 2008-01-31 00:00:00 구입가격 :  47.278187
# 판매일 2008-02-01 00:00:00 판매가격 46.151402 수익률 0.9761669160452365
# 진입일 : 2008-02-29 00:00:00 구입가격 :  49.879185
# 판매일 2008-03-03 00:00:00 판매가격 51.287678 수익률 1.028238091700977
# 진입일 : 2008-03-31 00:00:00 구입가격 :  44.78986
# 판매일 2008-04-01 00:00:00 판매가격 43.559784 수익률 0.9725367304117495
# ...

# %%
#Moon 누적 수익률

acc_rtn = 1.0

for i in df.index: 
    acc_rtn *= df.loc[i, 'return']
    df.loc[i,'acc_rtn'] = acc_rtn

print('누적수익률 : ', acc_rtn)
# Out:
# 누적수익률 :  1.165001849964831

# %% [markdown]
# # 절대 모멘텀을 함수화
#
# 1. 첫 번째 함수
#     - 매개변수 1개(데이터프레임)
#     - 데이터프레임에 결측치와 이상치를 제거
#     - 수정종가를 제외한 나머지 컬럼은 삭제
#     - 인덱스를 시계열로 변경
#     - 'STD-YM'파생변수를 생성하여 인덱스의 년-월 추출해서 대입
#
# 2. 두 번째 함수
#     - 매개변수 1개 (데이터프레임)
#     - 새로운 데이터프레임(df2) 생성
#     - 인자값으로 받아온 데이터프레임에서 년-월별 마지막 데이터들을 새로운 데이터프레임에 대입
#     - df2에 파생변수 2개 생성
#         - 'BF_1M' : 전월의 종가, 결측치는 0으로 대체
#         - 'BF_12M' : 전 년도의 종가, 결측치는 0으로 대체
#     - df2 리턴
# 3. 세 번째 함수
#     - 매개변수 2개(첫번째 함수의 결과(df1), 두 번째 함수의 결과(df2))
#     - df1에 trade컬럼을 생성, 값은 ''
#     - df1에 return 컬럼을 생성, 값은 '1'
#     - df2의 값들을 이용하여 momentum_index를 구하고 df1에 거래 내역 삽입
#     - df1의 거래 내역을 이용하여 수익을 return 컬럼에 대입
#     - return컬럼의 데이터를 가지고 누적수익률(acc_rtn)에 대입
#     - 누적수익률을 print를 이용하여 출력
#     - df1을 리턴

# %%
# zn : func_1

def func_1(x) : 
    # Moon : df의 인덱스가 Date 아니면, Date컬럼을 인덱스로 변경
    if 'Date' in x.columns :
        x = x.set_index('Date')
    # 결측치&이상치 제거
    x = x.loc[~x.isin([np.nan, np.inf, -np.inf]).any(axis = 'columns')]
    # 수정종가를 제외한 나머지 컬럼 삭제
    x= x[['Adj Close']]
    # 인덱스를 시계열로
    x.index = pd.to_datetime(x.index, format = '%Y-%m-%d')
    # STD-YM 컬럼 생성 
    x['STD-YM'] = list(map(lambda x : datetime.strftime(x, '%Y-%m'), x.index))

    return x

# %%
_df = pd.read_csv('../csv/GDX.csv')

# %%
_df1 = func_1(_df)
_df1
# Out:
#             Adj Close   STD-YM
# Date
# 2006-05-22  34.280224  2006-05
# 2006-05-23  34.952393  2006-05
# 2006-05-24  33.626480  2006-05
# 2006-05-25  35.283867  2006-05
# 2006-05-26  35.495640  2006-05
# ...               ...      ...
# 2019-06-18  23.670000  2019-06
# 2019-06-19  24.000000  2019-06
# 2019-06-20  25.049999  2019-06
# 2019-06-21  25.209999  2019-06
# 2019-06-24  25.703501  2019-06
#
# [3295 rows x 2 columns]

# %%
# func_2

def func_2(x) :

    y = x.loc[x['STD-YM'] != x.shift(-1)['STD-YM']] 

    #Moon   
    #  y = pd.DataFrame()
    # _list = x['STD_YM'].unique()
    # for i in _list : 
    #     last_df = df.loc[df['STD - YM'] == i].tail(1)
    #     y = pd.concat([y, last_df])
   
    y['BF_1M'] = y.shift(1)['Adj Close'].fillna(0)
    y['BF_12M'] = y.shift(12)['Adj Close'].fillna(0)

    return y

# %%
_df2 = func_2(_df1)
_df2
# Out:
# C:\Users\zino0\AppData\Local\Temp\ipykernel_5584\3483419058.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_1M'] = y.shift(1)['Adj Close'].fillna(0)
# C:\Users\zino0\AppData\Local\Temp\ipykernel_5584\3483419058.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_12M'] = y.shift(12)['Adj Close'].fillna(0)
#             Adj Close   STD-YM      BF_1M     BF_12M
# Date
# 2006-05-31  35.771877  2006-05   0.000000   0.000000
# ...

# %%
# Moon : func_3

def func_3(df1, df2) : 
    df1['trade'] = ''
    df1['return'] = 1

    for i in df2.index : 
        signal = ''

        momentum_index = df2.loc[i, 'BF_1M'] / df2.loc[i, 'BF_12M'] -1
        
        flag = True if ((momentum_index > 0) & (momentum_index != np.inf) & (momentum_index != -np.inf)) else False

        if flag : 
            signal = 'buy'

        df1.loc[i, 'trade'] = signal

    rtn = 1.0
    buy = 0
    sell = 0

    for i in df1.index :
        if (df1.loc[i, 'trade'] == 'buy') & (df1.shift(1).loc[i, 'trade'] == '') :
            buy = df1.loc[i, 'Adj Close']
            print('구입일 : ', i, '구입 가격 : ', buy)
        elif (df1.loc[i, 'trade'] == '') & (df1.shift(1).loc[i, 'trade'] == 'buy') :
            sell = df1.loc[i, 'Adj Close']
            print('판매일 : ', i, '판매 가격 : ', sell)
        
            rtn = (sell - buy) / buy + 1
            df1.loc[i,'return'] = rtn

    acc_rtn = 1.0

    for i in df1.index : 
        acc_rtn *= df1.loc[i, 'return']
        df1.loc[i, 'acc_rtn'] = acc_rtn
    print(acc_rtn)

    return df1

# %%
func_3(_df1, _df2)
# Out:
# C:\Users\zino0\AppData\Local\Temp\ipykernel_5584\2504965459.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   momentum_index = df2.loc[i, 'BF_1M'] / df2.loc[i, 'BF_12M'] -1
# C:\Users\zino0\AppData\Local\Temp\ipykernel_5584\2504965459.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = df2.loc[i, 'BF_1M'] / df2.loc[i, 'BF_12M'] -1
# 구입일 :  2007-05-31 00:00:00 구입 가격 :  36.162109
# 판매일 :  2007-06-01 00:00:00 판매 가격 :  36.993214
# 구입일 :  2007-06-29 00:00:00 구입 가격 :  34.989338
# 판매일 :  2007-07-02 00:00:00 판매 가격 :  35.866615
# 구입일 :  2007-09-28 00:00:00 구입 가격 :  41.878242
# 판매일 :  2007-10-01 00:00:00 판매 가격 :  42.312256
# 구입일 :  2007-10-31 00:00:00 구입 가격 :  46.72633
# 판매일 :  2007-11-01 00:00:00 판매 가격 :  45.082588
# 구입일 :  2007-11-30 00:00:00 구입 가격 :  42.810921
# 판매일 :  2007-12-03 00:00:00 판매 가격 :  43.235706
# 구입일 :  2007-12-31 00:00:00 구입 가격 :  43.033947
# 판매일 :  2008-01-02 00:00:00 판매 가격 :  46.235912
# ...
