# %%
import matplotlib.pyplot as plt

# %%
# 선 그래프 -> .plot(x,y)

x = [1,2,3,4]
y = [5,3,2,1]

plt.plot(x,y)  #  여기까지 써도, 나오긴 하는데 
                # plt.plot(y)와의 차이는 x가 1부터 시작하는지 여부야
plt.show()     # 까지 써줘. print 같은거야 언제나 붙여주자!!!!

# %%
# 막대그래프

x = [1,2,3,4]
y = [80, 70, 90, 60]

# plt.bar(x,y)
plt.barh(x,y) # 막대그래프 눕히기 ( X 의 값들이 많을때)
plt.show()

# %%
import numpy as np

# %%
x = np.random.rand(50)  # 값 랜덤으로 지정
y = np.random.rand(50)
color = np.random.rand(50)
area = (20*np.random.rand(50))**2

# s= scale , 크기. c = 색 . alpha = 투명도(0~1,1=완전불투명)
plt.scatter(x,y, s = area, c = color, alpha= 0.6)  
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# seaborn 라이브러리 설치

# !pip install seaborn

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# drinks.csv 파일 로드

drinks = pd.read_csv('../csv/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# 상관계수 행렬 출력
corr = drinks[[

    'beer_servings',
    'spirit_servings', 
    'wine_servings',
    'total_litres_of_pure_alcohol',
]].corr(method = 'pearson')

corr
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 히트맵 출력

cols_view = ['beer', 'spirit', 'wine', 'alcohol']

sns.set(font_scale = 1.5)

#기본적인 히트맵 형식 - 거의 이대로 써도 무방
hm = sns.heatmap(
    corr.values, 
    cbar = True, # 사이드바
    annot = True, # 히트맵 숫자 표시
    square= True, # 정사각형, 직사각형
    fmt = '.2f',  # 소수점 표시
    annot_kws = {'size' : 20}, # 히트맵 숫자 크기
    xticklabels = cols_view, # x축 이름
    yticklabels= cols_view # y축 이름
)

plt.tight_layout()
plt.show()

# %%
hm = sns.heatmap(
    corr.values, 
    cbar = False,
    annot = True, 
    square= True,
    fmt = '.2f',
    annot_kws = {'size' : 20},
    xticklabels = cols_view,
    yticklabels= cols_view
)

plt.tight_layout()
plt.show()

# %%
hm = sns.heatmap(
    corr.values, 
    cbar = True, 
    annot = False, 
    square= True,
    fmt = '.2f',
    annot_kws = {'size' : 20},
    xticklabels = cols_view,
    yticklabels= cols_view
)

plt.tight_layout()
plt.show()

# %%
hm = sns.heatmap(
    corr.values, 
    cbar = True,
    annot = True, 
    annot_kws = {'size' : 20},
    xticklabels = cols_view,
    yticklabels= cols_view
)

plt.tight_layout()
plt.show()

# %%
sns.set(style = 'whitegrid', context = 'notebook')

sns.pairplot(drinks[[

    'beer_servings',
    'spirit_servings', 
    'wine_servings',
    'total_litres_of_pure_alcohol',
]],
height = 2.5)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB
