# %%
import pandas as pd
import momentum as mm

import imp
imp.reload(mm)
# Out:
# <module 'momentum' from 'c:\\Users\\zino0\\Documents\\GitHub\\Practice_ubion\\Code_Moon\\230417\\momentum.py'>

# %%
df = pd.read_csv('../csv/AAPL.csv')

# %%
df1 = mm.func_1(df, 'Close')
df1.head()
# Out:
#                 Close   STD-YM
# Date
# 2010-01-04  30.572857  2010-01
# 2010-01-05  30.625713  2010-01
# 2010-01-06  30.138571  2010-01
# 2010-01-07  30.082857  2010-01
# 2010-01-08  30.282858  2010-01

# %%
df2 = mm.func_2(df1)
df2.iloc[8:15]
# Out:
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_1M'] = y.shift(1)[col].fillna(0)
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_12M'] = y.shift(12)[col].fillna(0)
#                 Close   STD-YM      BF_1M     BF_12M
# Date
# 2010-09-30  40.535713  2010-09  34.728573   0.000000
# ...

# %%
mm.func_3(df1, df2)
# Out:
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:51: RuntimeWarning: invalid value encountered in scalar divide
#   momentum_index = df2.loc[i, 'BF_1M'] / df2.loc[i, 'BF_12M'] -1
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:51: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = df2.loc[i, 'BF_1M'] / df2.loc[i, 'BF_12M'] -1
# 구입일 :  2011-01-31 00:00:00 구입 가격 :  48.474285
# 판매일 :  2011-02-01 00:00:00 판매 가격 :  49.290001
# 구입일 :  2011-02-28 00:00:00 구입 가격 :  50.458572
# 판매일 :  2011-03-01 00:00:00 판매 가격 :  49.901428
# 구입일 :  2011-03-31 00:00:00 구입 가격 :  49.787144
# 판매일 :  2011-04-01 00:00:00 판매 가격 :  49.222858
# 구입일 :  2011-04-29 00:00:00 구입 가격 :  50.01857
# 판매일 :  2011-05-02 00:00:00 판매 가격 :  49.468571
# 구입일 :  2011-05-31 00:00:00 구입 가격 :  49.689999
# 판매일 :  2011-06-01 00:00:00 판매 가격 :  49.35857
# 구입일 :  2011-06-30 00:00:00 구입 가격 :  47.952858
# 판매일 :  2011-07-01 00:00:00 판매 가격 :  49.037144
# ...

# %%
import invest # 폴더 invest 안에 있는 init을 자동으로 불러온다

import imp
imp.reload(invest)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 4
#       1 import invest # 폴더 invest 안에 있는 init을 자동으로 불러온다
#       3 import imp
# ----> 4 imp.reload(invest)
#
# File c:\Users\zino0\AppData\Local\Programs\Python\Python311\Lib\imp.py:315, in reload(module)
#     307 def reload(module):
#     308     """**DEPRECATED**
#     309
#     310     Reload the module and return it.
#    (...)
#     313
#     314     """
# --> 315     return importlib.reload(module)
#
# File c:\Users\zino0\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:169, in reload(module)
#     167 if spec is None:
#     168     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169 _bootstrap._exec(spec, module)
#     170 # The module may have replaced itself in sys.modules!
#     171 return sys.modules[name]
#
# ...

# %%
test = invest.Invest(df, 'Close')

# %%
test.momentum()
# Out:
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_1M'] = y.shift(1)[col].fillna(0)
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['BF_12M'] = y.shift(12)[col].fillna(0)
# c:\Users\zino0\Documents\GitHub\Practice_ubion\Code_Moon\230417\momentum.py:51: RuntimeWarning: invalid value encountered in scalar divide
# ...
